# %%
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import VotingClassifier

from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

from sklearn.externals.joblib import Parallel, delayed
from sklearn.utils import shuffle

import time
import numpy as np
import scipy.sparse as sparse

import pandas as pd
import re
from io import StringIO

# %%
def trainModel(name, name_estimator, clazz, params, dataset, path):
    Xtrain, Ytrain = loadTrainDataSet(name, dataset, path)
    model = clazz(**params)
    start = time.time() # Start time
    model.fit(Xtrain, Ytrain)
    end = time.time()
    elapsed = end - start
    print("\t", name_estimator, " - Time taken for training:", elapsed, "seconds")
    return (name_estimator, model)

def loadTrainDataSet(name, dataset, path):
    train = sparse.load_npz(path+dataset)
    #train = shuffle(train)
    Xtrain = train[:,:-1]
    Ytrain = train[:,-1].A.reshape(train[:,-1].A.shape[0],)
    print("Train dataset loaded: "+name)
    return Xtrain, Ytrain

def simple_voting(lista):
    return np.argmax(np.bincount(lista))

def report_to_df(dataset, model, report):
    report = "Classes" + re.sub(r"( +)|(avg / total(.*))", " ", report).replace("\n ", "\n")
    report_df = pd.read_csv(StringIO(report), sep=' ')
    report_df["DataSet"] = dataset
    report_df["Model"] = model
    report_df.set_index('DataSet', inplace=True)
    return(report_df[['Model','Classes','precision','recall','f1-score','support']])

# %%
estimators = {"KNeighbors": (KNeighborsClassifier, {}),
              "MultinomialNB" : (MultinomialNB, {}),
              "RandomForest" : (RandomForestClassifier, {"n_estimators":100}),
              "LogisticRegression" : (LogisticRegression, {}),
              "MLP" : (MLPClassifier, {"hidden_layer_sizes":100}),
              #"MLP" : (MLPClassifier, {"hidden_layer_sizes":100, "max_iter":1500}),
              "SVM" : (SVC, {"cache_size":1000}),
              "LinearSVC" : (LinearSVC, {})
             }

datasets = {"Sin Balancear": "centroids_train.npz",
            "Kmeans": "data_temp.npz",
            "Kmeans+Adasyn": "train_1.npz",
            "Kmeans+Smote": "train_3.npz",
            "Kmeans+SmoteEnn": "train_4.npz",
            "Kmeans+SmoteTomek": "train_5.npz",
            "Kmeans+AdasynEnn": "train_6.npz",
            "Kmeans+AdasynTomek": "train_9.npz"
           }

# %%
path_train = "../hufa_train_wiki_w2v/"
path_test = "../hufa_test_wiki_w2v/centroids_test.npz"

test = sparse.load_npz(path_test).astype(float)
#test = shuffle(test)
Xtest = test[:,:-1]
Ytest = test[:,-1].A.reshape(test[:,-1].A.shape[0],)
#del test
print("Test dataset loaded ")
# Out:
# Test dataset loaded

# %%
runs = []
for (name, dataset) in datasets.items():
    #Xtrain, Ytrain, name = loadTrainDataSet(name, dataset, path_train)
    #print("Train dataset loaded: "+name)
    models = Parallel(n_jobs=len(estimators))(delayed(trainModel)(name, name_estimator, clazz, params, dataset, path_train) for (name_estimator, (clazz, params)) in estimators.items())
    runs.append({"name":name, "models":models})
# Out:
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# Train dataset loaded: Kmeans+AdasynTomek
# 	 MultinomialNB  - Time taken for training: 0.05394482612609863 seconds
# 	 KNeighbors  - Time taken for training: 0.03136897087097168 seconds
# 	 LinearSVC  - Time taken for training: 14.238010883331299 seconds
# 	 LogisticRegression  - Time taken for training: 15.202873945236206 seconds
# 	 RandomForest  - Time taken for training: 18.905710220336914 seconds
# 	 SVM  - Time taken for training: 339.05274748802185 seconds
# 	 MLP  - Time taken for training: 612.7561783790588 seconds
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# Train dataset loaded: Kmeans+SmoteTomek
# 	 KNeighbors  - Time taken for training: 0.01944875717163086 seconds
# 	 MultinomialNB  - Time taken for training: 0.055921077728271484 seconds
# 	 LogisticRegression  - Time taken for training: 1.4251132011413574 seconds
# 	 LinearSVC  - Time taken for training: 2.3067381381988525 seconds
# 	 RandomForest  - Time taken for training: 9.910195589065552 seconds
# 	 SVM  - Time taken for training: 135.38359951972961 seconds
# 	 MLP  - Time taken for training: 372.76460242271423 seconds
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# Train dataset loaded: Kmeans+Smote
# 	 MultinomialNB  - Time taken for training: 0.04256439208984375 seconds
# 	 KNeighbors  - Time taken for training: 0.02589869499206543 seconds
# 	 LogisticRegression  - Time taken for training: 1.2970280647277832 seconds
# 	 LinearSVC  - Time taken for training: 2.615964889526367 seconds
# 	 RandomForest  - Time taken for training: 10.179658651351929 seconds
# 	 SVM  - Time taken for training: 140.93594646453857 seconds
# 	 MLP  - Time taken for training: 372.8401141166687 seconds
# Train dataset loaded: Sin Balancear
# Train dataset loaded: Sin Balancear
# Train dataset loaded: Sin Balancear
# Train dataset loaded: Sin Balancear
# 	 KNeighbors  - Time taken for training: 0.04938077926635742 seconds
# Train dataset loaded: Sin Balancear
# Train dataset loaded: Sin Balancear
# Train dataset loaded: Sin Balancear
# 	 MultinomialNB  - Time taken for training: 0.26306891441345215 seconds
# 	 LogisticRegression  - Time taken for training: 19.77811598777771 seconds
# 	 LinearSVC  - Time taken for training: 32.73846459388733 seconds
# 	 RandomForest  - Time taken for training: 85.15421342849731 seconds
# 	 SVM  - Time taken for training: 442.56295943260193 seconds
# 	 MLP  - Time taken for training: 2792.712392807007 seconds
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# Train dataset loaded: Kmeans+Adasyn
# 	 KNeighbors  - Time taken for training: 0.025020122528076172 seconds
# 	 MultinomialNB  - Time taken for training: 0.05114579200744629 seconds
# 	 LinearSVC  - Time taken for training: 13.946232318878174 seconds
# 	 LogisticRegression  - Time taken for training: 14.542615413665771 seconds
# 	 RandomForest  - Time taken for training: 18.528306484222412 seconds
# 	 SVM  - Time taken for training: 359.1129002571106 seconds
# 	 MLP  - Time taken for training: 538.3259818553925 seconds
# Train dataset loaded: Kmeans
# Train dataset loaded: Kmeans
# Train dataset loaded: Kmeans
# Train dataset loaded: Kmeans
# 	 KNeighbors  - Time taken for training: 0.0022165775299072266 seconds
# Train dataset loaded: Kmeans
# Train dataset loaded: Kmeans
# Train dataset loaded: Kmeans
# 	 MultinomialNB  - Time taken for training: 0.019507884979248047 seconds
# 	 LogisticRegression  - Time taken for training: 0.8397910594940186 seconds
# 	 LinearSVC  - Time taken for training: 1.1097214221954346 seconds
# 	 RandomForest  - Time taken for training: 6.7277936935424805 seconds
# 	 SVM  - Time taken for training: 28.12819218635559 seconds
# 	 MLP  - Time taken for training: 355.37149262428284 seconds
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# Train dataset loaded: Kmeans+SmoteEnn
# 	 KNeighbors  - Time taken for training: 0.019386768341064453 seconds
# 	 MultinomialNB  - Time taken for training: 0.062422752380371094 seconds
# 	 LogisticRegression  - Time taken for training: 0.6426105499267578 seconds
# 	 LinearSVC  - Time taken for training: 1.1632227897644043 seconds
# 	 RandomForest  - Time taken for training: 4.533413648605347 seconds
# 	 SVM  - Time taken for training: 98.49825501441956 seconds
# 	 MLP  - Time taken for training: 262.6785671710968 seconds
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# Train dataset loaded: Kmeans+AdasynEnn
# 	 KNeighbors  - Time taken for training: 0.037946224212646484 seconds
# 	 MultinomialNB  - Time taken for training: 0.04866290092468262 seconds
# 	 LogisticRegression  - Time taken for training: 4.103172540664673 seconds
# 	 LinearSVC  - Time taken for training: 6.70549750328064 seconds
# 	 RandomForest  - Time taken for training: 7.446378469467163 seconds
# 	 SVM  - Time taken for training: 264.07586455345154 seconds
# 	 MLP  - Time taken for training: 433.4490776062012 seconds

# %%
print("Obteniendo resultados:")
df_results = pd.DataFrame()
for run in runs:
    print ("\n\nDATASET: ", run["name"], "\n\n")
    results = []
    for (name_estimator, model) in run["models"]:
        start = time.time() # Start time
        if name_estimator == "KNeighbors":
            result = [y for x in [Xtest[i:i+5000,:] for i in range(0,Xtest.shape[0],5000)] for y in model.predict(x)]
        else:
            result = model.predict(Xtest)
        end = time.time()
        elapsed = end - start
        results.append(list(result))
        print("DataSet: ", run["name"]," ----- Modelo: ", name_estimator, " ----- Time taken for prediction:", elapsed,"seconds\n", classification_report(Ytest, result, digits=4), "\n")
        df_results = pd.concat([df_results, report_to_df(run["name"], name_estimator, classification_report(Ytest, result, digits=4))])
    start = time.time() # Start time
    result_voting = [simple_voting([x[i] for x in results]) for i in range(0, len(results[0]))]
    df_results = pd.concat([df_results, report_to_df(run["name"], name_estimator, classification_report(Ytest, result_voting, digits=4))])
    end = time.time()
    elapsed = end - start
    print("DataSet: ", run["name"]," ----- Modelo: Voting ----- Time taken for prediction:", elapsed,"seconds\n", classification_report(Ytest, result_voting, digits=4), "\n")
# Out:
# Obteniendo resultados:
#
#
# DATASET:  Kmeans+AdasynTomek
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.021590709686279297 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.8274    0.9054     54473
#         1.0     0.0494    0.9722    0.0941       503
#
# avg / total     0.9910    0.8287    0.8980     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  RandomForest  ----- Time taken for prediction: 1.9457101821899414 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    1.0000    0.9996     54473
#         1.0     0.9957    0.9125    0.9523       503
#
# avg / total     0.9992    0.9992    0.9991     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  SVM  ----- Time taken for prediction: 609.8878281116486 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9994    0.9317    0.9643     54473
#         1.0     0.1125    0.9384    0.2010       503
#
# avg / total     0.9913    0.9317    0.9574     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.010040760040283203 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9998    0.9410    0.9695     54473
#         1.0     0.1332    0.9821    0.2346       503
#
# avg / total     0.9919    0.9414    0.9628     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  MLP  ----- Time taken for prediction: 0.43614935874938965 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9999    0.9827    0.9912     54473
#         1.0     0.3454    0.9861    0.5116       503
#
# avg / total     0.9939    0.9828    0.9868     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.009441614151000977 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9998    0.9648    0.9820     54473
#         1.0     0.2046    0.9821    0.3387       503
#
# avg / total     0.9926    0.9649    0.9761     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 85.80474734306335 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.7290    0.8431     54473
#         1.0     0.0322    0.9781    0.0624       503
#
# avg / total     0.9909    0.7312    0.8360     54976
#
#
# DataSet:  Kmeans+AdasynTomek  ----- Modelo: Voting ----- Time taken for prediction: 0.18479323387145996 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9998    0.9846    0.9921     54473
#         1.0     0.3694    0.9781    0.5362       503
#
# avg / total     0.9940    0.9845    0.9880     54976
#
#
#
#
# DATASET:  Kmeans+SmoteTomek
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.020626544952392578 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9994    0.9719    0.9855     54473
#         1.0     0.2358    0.9404    0.3770       503
#
# avg / total     0.9924    0.9716    0.9799     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  RandomForest  ----- Time taken for prediction: 2.1589548587799072 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    1.0000    0.9996     54473
#         1.0     1.0000    0.9125    0.9543       503
#
# avg / total     0.9992    0.9992    0.9992     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  SVM  ----- Time taken for prediction: 277.60473465919495 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9992    0.9992     54473
#         1.0     0.9165    0.9165    0.9165       503
#
# avg / total     0.9985    0.9985    0.9985     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.011284351348876953 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9947    0.9972     54473
#         1.0     0.6286    0.9622    0.7604       503
#
# avg / total     0.9963    0.9945    0.9950     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  MLP  ----- Time taken for prediction: 0.422060489654541 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9966    0.9981     54473
#         1.0     0.7237    0.9583    0.8246       503
#
# avg / total     0.9971    0.9963    0.9965     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.013181209564208984 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9955    0.9976     54473
#         1.0     0.6630    0.9622    0.7851       503
#
# avg / total     0.9966    0.9952    0.9956     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 80.27530646324158 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9995    0.9753    0.9873     54473
#         1.0     0.2614    0.9463    0.4096       503
#
# avg / total     0.9927    0.9750    0.9820     54976
#
#
# DataSet:  Kmeans+SmoteTomek  ----- Modelo: Voting ----- Time taken for prediction: 0.18227148056030273 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9995    0.9976    0.9985     54473
#         1.0     0.7809    0.9423    0.8541       503
#
# avg / total     0.9975    0.9971    0.9972     54976
#
#
#
#
# DATASET:  Kmeans+Smote
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.021181583404541016 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9995    0.9712    0.9851     54473
#         1.0     0.2318    0.9423    0.3721       503
#
# avg / total     0.9924    0.9709    0.9795     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  RandomForest  ----- Time taken for prediction: 1.9508402347564697 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    1.0000    0.9996     54473
#         1.0     1.0000    0.9145    0.9553       503
#
# avg / total     0.9992    0.9992    0.9992     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  SVM  ----- Time taken for prediction: 286.59721779823303 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9992    0.9992     54473
#         1.0     0.9129    0.9165    0.9147       503
#
# avg / total     0.9984    0.9984    0.9984     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.010373115539550781 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9944    0.9970     54473
#         1.0     0.6117    0.9583    0.7467       503
#
# avg / total     0.9961    0.9941    0.9947     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  MLP  ----- Time taken for prediction: 0.40471363067626953 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.9965    0.9981     54473
#         1.0     0.7202    0.9622    0.8238       503
#
# avg / total     0.9971    0.9962    0.9965     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.012555599212646484 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.9954    0.9975     54473
#         1.0     0.6603    0.9662    0.7845       503
#
# avg / total     0.9966    0.9951    0.9956     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 81.1823947429657 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9995    0.9700    0.9845     54473
#         1.0     0.2257    0.9483    0.3647       503
#
# avg / total     0.9924    0.9698    0.9788     54976
#
#
# DataSet:  Kmeans+Smote  ----- Modelo: Voting ----- Time taken for prediction: 0.17940711975097656 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9994    0.9975    0.9985     54473
#         1.0     0.7741    0.9404    0.8492       503
#
# avg / total     0.9974    0.9969    0.9971     54976
#
#
#
#
# DATASET:  Sin Balancear
#
#
# DataSet:  Sin Balancear  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.020543575286865234 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9959    0.9976     54473
#         1.0     0.6764    0.9185    0.7791       503
#
# avg / total     0.9963    0.9952    0.9956     54976
# DataSet:  Sin Balancear  ----- Modelo:  RandomForest  ----- Time taken for prediction: 2.4691336154937744 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9987    1.0000    0.9993     54473
#         1.0     1.0000    0.8549    0.9218       503
#
# avg / total     0.9987    0.9987    0.9986     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo:  SVM  ----- Time taken for prediction: 111.48017978668213 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9943    1.0000    0.9971     54473
#         1.0     0.9948    0.3797    0.5496       503
#
# avg / total     0.9943    0.9943    0.9930     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.013540506362915039 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9994    0.9994     54473
#         1.0     0.9391    0.9205    0.9297       503
#
# avg / total     0.9987    0.9987    0.9987     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo:  MLP  ----- Time taken for prediction: 0.42828869819641113 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9994    0.9995    0.9995     54473
#         1.0     0.9458    0.9364    0.9411       503
#
# avg / total     0.9989    0.9989    0.9989     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.016053199768066406 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9996    0.9994     54473
#         1.0     0.9530    0.9264    0.9395       503
#
# avg / total     0.9989    0.9989    0.9989     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 703.4098105430603 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9986    1.0000    0.9993     54473
#         1.0     1.0000    0.8429    0.9148       503
#
# avg / total     0.9986    0.9986    0.9985     54976
#
#
# DataSet:  Sin Balancear  ----- Modelo: Voting ----- Time taken for prediction: 0.18567800521850586 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9999    0.9996     54473
#         1.0     0.9935    0.9105    0.9502       503
#
# avg / total     0.9991    0.9991    0.9991     54976
#
#
#
#
# DATASET:  Kmeans+Adasyn
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.02434396743774414 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.8997    0.9471     54473
#         1.0     0.0820    0.9702    0.1512       503
#
# avg / total     0.9913    0.9003    0.9398     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  RandomForest  ----- Time taken for prediction: 1.9936721324920654 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    1.0000    0.9996     54473
#         1.0     1.0000    0.9145    0.9553       503
#
# avg / total     0.9992    0.9992    0.9992     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  SVM  ----- Time taken for prediction: 635.3922319412231 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9239    0.9601     54473
#         1.0     0.1012    0.9284    0.1825       503
#
# avg / total     0.9911    0.9239    0.9530     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.009894132614135742 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9999    0.9143    0.9552     54473
#         1.0     0.0964    0.9901    0.1756       503
#
# avg / total     0.9916    0.9150    0.9480     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  MLP  ----- Time taken for prediction: 0.3657956123352051 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9999    0.9843    0.9920     54473
#         1.0     0.3669    0.9861    0.5348       503
#
# avg / total     0.9941    0.9843    0.9878     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.012436389923095703 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9999    0.9630    0.9811     54473
#         1.0     0.1979    0.9881    0.3298       503
#
# avg / total     0.9925    0.9633    0.9752     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 89.33371567726135 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9998    0.7051    0.8270     54473
#         1.0     0.0298    0.9821    0.0579       503
#
# avg / total     0.9909    0.7076    0.8199     54976
#
#
# DataSet:  Kmeans+Adasyn  ----- Modelo: Voting ----- Time taken for prediction: 0.17930984497070312 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9999    0.9859    0.9928     54473
#         1.0     0.3927    0.9861    0.5617       503
#
# avg / total     0.9943    0.9859    0.9889     54976
#
#
#
#
# DATASET:  Kmeans
#
#
# DataSet:  Kmeans  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.020146846771240234 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9860    0.9926     54473
#         1.0     0.3796    0.9245    0.5382       503
#
# avg / total     0.9936    0.9855    0.9885     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  RandomForest  ----- Time taken for prediction: 2.215553045272827 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    1.0000    0.9996     54473
#         1.0     0.9978    0.9125    0.9533       503
#
# avg / total     0.9992    0.9992    0.9992     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  SVM  ----- Time taken for prediction: 97.68781018257141 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9957    1.0000    0.9978     54473
#         1.0     0.9963    0.5328    0.6943       503
#
# avg / total     0.9957    0.9957    0.9951     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.00985860824584961 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9950    0.9973     54473
#         1.0     0.6393    0.9583    0.7669       503
#
# avg / total     0.9963    0.9947    0.9952     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  MLP  ----- Time taken for prediction: 0.36719226837158203 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9996    0.9972    0.9984     54473
#         1.0     0.7591    0.9523    0.8448       503
#
# avg / total     0.9974    0.9968    0.9970     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.012126684188842773 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9997    0.9969    0.9983     54473
#         1.0     0.7423    0.9622    0.8381       503
#
# avg / total     0.9973    0.9966    0.9968     54976
#
#
# DataSet:  Kmeans  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 45.795870780944824 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9986    0.9999    0.9993     54473
#         1.0     0.9930    0.8469    0.9142       503
#
# avg / total     0.9985    0.9985    0.9985     54976
#
#
# DataSet:  Kmeans  ----- Modelo: Voting ----- Time taken for prediction: 0.17968153953552246 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9987    0.9990     54473
#         1.0     0.8657    0.9225    0.8932       503
#
# avg / total     0.9981    0.9980    0.9980     54976
#
#
#
#
# DATASET:  Kmeans+SmoteEnn
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.020076513290405273 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9896    0.9944     54473
#         1.0     0.4495    0.9205    0.6040       503
#
# avg / total     0.9942    0.9890    0.9908     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  RandomForest  ----- Time taken for prediction: 1.997976541519165 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9989    1.0000    0.9994     54473
#         1.0     1.0000    0.8807    0.9366       503
#
# avg / total     0.9989    0.9989    0.9989     54976
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  SVM  ----- Time taken for prediction: 188.9189908504486 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9991    0.9997    0.9994     54473
#         1.0     0.9640    0.9046    0.9333       503
#
# avg / total     0.9988    0.9988    0.9988     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.01013493537902832 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9991    0.9999    0.9995     54473
#         1.0     0.9913    0.9066    0.9470       503
#
# avg / total     0.9991    0.9991    0.9991     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  MLP  ----- Time taken for prediction: 0.37743425369262695 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9991    1.0000    0.9995     54473
#         1.0     0.9956    0.9046    0.9479       503
#
# avg / total     0.9991    0.9991    0.9991     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.01236104965209961 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9998    0.9995     54473
#         1.0     0.9786    0.9085    0.9423       503
#
# avg / total     0.9990    0.9990    0.9990     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 77.05415725708008 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9988    0.9999    0.9993     54473
#         1.0     0.9821    0.8728    0.9242       503
#
# avg / total     0.9987    0.9987    0.9987     54976
#
#
# DataSet:  Kmeans+SmoteEnn  ----- Modelo: Voting ----- Time taken for prediction: 0.1777174472808838 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9991    0.9999    0.9995     54473
#         1.0     0.9913    0.9066    0.9470       503
#
# avg / total     0.9991    0.9991    0.9991     54976
#
#
#
#
# DATASET:  Kmeans+AdasynEnn
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  MultinomialNB  ----- Time taken for prediction: 0.02089834213256836 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9995    0.9418    0.9698     54473
#         1.0     0.1308    0.9483    0.2299       503
#
# avg / total     0.9915    0.9419    0.9630     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  RandomForest  ----- Time taken for prediction: 1.705542802810669 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9989    1.0000    0.9994     54473
#         1.0     1.0000    0.8787    0.9354       503
#
# avg / total     0.9989    0.9989    0.9989     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  SVM  ----- Time taken for prediction: 461.6425530910492 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9955    0.9974     54473
#         1.0     0.6544    0.9225    0.7657       503
#
# avg / total     0.9961    0.9948    0.9953     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  LinearSVC  ----- Time taken for prediction: 0.009010076522827148 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9994    0.9778    0.9885     54473
#         1.0     0.2793    0.9324    0.4299       503
#
# avg / total     0.9928    0.9774    0.9833     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  MLP  ----- Time taken for prediction: 0.366199254989624 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9963    0.9978     54473
#         1.0     0.6964    0.9165    0.7914       503
#
# avg / total     0.9965    0.9956    0.9959     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  LogisticRegression  ----- Time taken for prediction: 0.012604713439941406 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9993    0.9924    0.9958     54473
#         1.0     0.5284    0.9245    0.6725       503
#
# avg / total     0.9950    0.9918    0.9929     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo:  KNeighbors  ----- Time taken for prediction: 79.39224433898926 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9991    0.8654    0.9275     54473
#         1.0     0.0592    0.9165    0.1111       503
#
# avg / total     0.9905    0.8659    0.9200     54976
#
#
# DataSet:  Kmeans+AdasynEnn  ----- Modelo: Voting ----- Time taken for prediction: 0.1820068359375 seconds
#               precision    recall  f1-score   support
#
#         0.0     0.9992    0.9976    0.9984     54473
#         1.0     0.7778    0.9185    0.8423       503
#
# avg / total     0.9972    0.9969    0.9970     54976

# %%
df_results.to_csv("../Resultados/BoC_Wiki.csv", float_format='%.4f')

# %%
resultado = runs[2]['models'][1][1].predict(Xtest)

# %%
confusion_matrix(Ytest, resultado)
# Out:
# array([[54473,     0],
#        [   43,   460]])

# %%
diferencias = resultado == Ytest

# %%
np.where(diferencias == False)[0]
# Out:
# array([54473, 54478, 54482, 54501, 54508, 54509, 54532, 54539, 54558,
#        54562, 54580, 54585, 54617, 54632, 54637, 54639, 54641, 54643,
#        54657, 54696, 54698, 54715, 54730, 54746, 54767, 54769, 54770,
#        54774, 54791, 54814, 54827, 54830, 54838, 54841, 54844, 54848,
#        54852, 54855, 54876, 54917, 54926, 54928, 54932])

# %%
mini_path_test = "../hufa_test_wiki_w2v/minitest_centroids_test.npz"

test = sparse.load_npz(mini_path_test).astype(float)
#test = shuffle(test)
Xtest = test[:,:-1]
Ytest = test[:,-1].A.reshape(test[:,-1].A.shape[0],)

# %%
mini_resultado = runs[2]['models'][1][1].predict(Xtest)

# %%
confusion_matrix(Ytest, mini_resultado)
# Out:
# array([[ 0,  0],
#        [43,  0]])

# %%
tn, fp, fn, tp = confusion_matrix(Ytest, mini_resultado).ravel()
(tn, fp, fn, tp)
# Out:
# (0, 0, 43, 0)
